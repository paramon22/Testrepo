# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# !pip install yfinance
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import matplotlib.pyplot as plt
import yfinance as yf

# %%
stock_data = yf.Ticker("TSLA")
prices = stock_data.history(period="1y")
prices
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2022-04-22 00:00:00-04:00  338.303345  344.950012  331.333344  335.016663
# 2022-04-25 00:00:00-04:00  326.323334  336.206665  325.100006  332.673340
# 2022-04-26 00:00:00-04:00  331.809998  333.333344  291.666656  292.140015
# 2022-04-27 00:00:00-04:00  299.526672  306.000000  292.453339  293.836670
# 2022-04-28 00:00:00-04:00  299.993347  300.000000  273.899994  292.503326
# ...                               ...         ...         ...         ...
# 2023-04-17 00:00:00-04:00  186.320007  189.690002  182.690002  187.039993
# 2023-04-18 00:00:00-04:00  187.149994  187.690002  183.580002  184.309998
# 2023-04-19 00:00:00-04:00  179.100006  183.500000  177.649994  180.589996
# 2023-04-20 00:00:00-04:00  166.169998  169.699997  160.559998  162.990005
# 2023-04-21 00:00:00-04:00  164.800003  166.000000  161.320007  165.080002
#
#                               Volume  Dividends  Stock Splits
# Date
# ...

# %%
def make_graph(z, xlab, ylab, title):
    plt.plot(z)
    plt.xlabel(xlab)
    plt.ylabel(ylab)
    plt.title(title)
    plt.show()

data = prices['Close']  
xlaba = 'Date'
ylaba = 'Stock Price'
ttt = 'Historical Quotes for TSLA for the Past Trailing Year'

make_graph(data,xlaba,ylaba,ttt)
